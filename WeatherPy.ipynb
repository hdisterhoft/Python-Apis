# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"


for city in cities:
    query_url = url + "appid=" + api_key + "&q=" + city
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    pprint(weather_json)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': -23.12, 'lon': -134.97},
#  'dt': 1541295202,
#  'id': 4030556,
#  'main': {'grnd_level': 1031.86,
#           'humidity': 95,
#           'pressure': 1031.86,
#           'sea_level': 1031.92,
#           'temp': 297.22,
#           'temp_max': 297.22,
#           'temp_min': 297.22},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF',
#          'message': 0.0032,
#          'sunrise': 1541340746,
#          'sunset': 1541387681},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 65.0012, 'speed': 9.18}}
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': 40.29, 'lon': 97.04},
#  'dt': 1541295202,
#  'id': 1528998,
#  'main': {'grnd_level': 858.24,
#           'humidity': 62,
#           'pressure': 858.24,
#           'sea_level': 1045.79,
#           'temp': 273.245,
#           'temp_max': 273.245,
#           'temp_min': 273.245},
#  'name': 'Yumen',
#  'sys': {'country': 'CN',
#          'message': 0.0033,
#          'sunrise': 1541289862,
#          'sunset': 1541327151},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 95.0012, 'speed': 1.88}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 19.71, 'lon': -155.08},
#  'dt': 1541292960,
#  'id': 5855927,
#  'main': {'humidity': 72,
#           'pressure': 1014,
#           'temp': 295.05,
#           'temp_max': 300.35,
#           'temp_min': 290.75},
#  'name': 'Hilo',
#  'sys': {'country': 'US',
#          'id': 818,
#          'message': 0.0036,
#          'sunrise': 1541348579,
#          'sunset': 1541389469,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 90, 'speed': 4.6}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -42.88, 'lon': 147.33},
#  'dt': 1541293200,
#  'id': 2163355,
#  'main': {'humidity': 48,
#           'pressure': 1005,
#           'temp': 289.15,
#           'temp_max': 289.15,
#           'temp_min': 289.15},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 8195,
#          'message': 0.0037,
#          'sunrise': 1541271042,
#          'sunset': 1541321907,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'speed': 3.6}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -11.11, 'lon': -77.61},
#  'dt': 1541295202,
#  'id': 3940002,
#  'main': {'grnd_level': 988.9,
#           'humidity': 91,
#           'pressure': 988.9,
#           'sea_level': 1028.24,
#           'temp': 289.545,
#           'temp_max': 289.545,
#           'temp_min': 289.545},
#  'name': 'Huacho',
#  'sys': {'country': 'PE',
#          'message': 0.0034,
#          'sunrise': 1541327879,
#          'sunset': 1541373004},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 152.001, 'speed': 2.16}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 44.08, 'lon': -103.23},
#  'dt': 1541292960,
#  'id': 5768233,
#  'main': {'humidity': 100,
#           'pressure': 1019,
#           'temp': 273.64,
#           'temp_max': 275.35,
#           'temp_min': 270.95},
#  'name': 'Rapid City',
#  'sys': {'country': 'US',
#          'id': 2454,
#          'message': 0.0039,
#          'sunrise': 1541338421,
#          'sunset': 1541374720,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 360, 'speed': 4.1}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -0.74, 'lon': -90.35},
#  'dt': 1541289600,
#  'id': 3652764,
#  'main': {'humidity': 69,
#           'pressure': 1011,
#           'temp': 298.15,
#           'temp_max': 298.15,
#           'temp_min': 298.15},
#  'name': 'Puerto Ayora',
#  'sys': {'country': 'EC',
#          'id': 4355,
#          'message': 0.0051,
#          'sunrise': 1541331639,
#          'sunset': 1541375353,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 100, 'speed': 4.1}}
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': 8.07, 'lon': 22.4},
#  'dt': 1541295203,
#  'id': 236901,
#  'main': {'grnd_level': 947.4,
#           'humidity': 89,
#           'pressure': 947.4,
#           'sea_level': 1023.13,
#           'temp': 292.245,
#           'temp_max': 292.245,
#           'temp_min': 292.245},
#  'name': 'Ouadda',
#  'sys': {'country': 'CF',
#          'message': 0.0032,
#          'sunrise': 1541305161,
#          'sunset': 1541347704},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 151.501, 'speed': 1.28}}
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': 63.9, 'lon': 122.77},
#  'dt': 1541295203,
#  'id': 2021017,
#  'main': {'grnd_level': 1007.95,
#           'humidity': 63,
#           'pressure': 1007.95,
#           'sea_level': 1029.57,
#           'temp': 261.82,
#           'temp_max': 261.82,
#           'temp_min': 261.82},
#  'name': 'Kysyl-Syr',
#  'sys': {'country': 'RU',
#          'message': 0.0042,
#          'sunrise': 1541288333,
#          'sunset': 1541316298},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 190.501, 'speed': 2.63}}
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': -2.54, 'lon': 112.95},
#  'dt': 1541295204,
#  'id': 1628884,
#  'main': {'grnd_level': 1015.41,
#           'humidity': 77,
#           'pressure': 1015.41,
#           'sea_level': 1024.22,
#           'temp': 303.87,
#           'temp_max': 303.87,
#           'temp_min': 303.87},
#  'name': 'Sampit',
#  'sys': {'country': 'ID',
#          'message': 0.0034,
#          'sunrise': 1541282729,
#          'sunset': 1541326679},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 65.0012, 'speed': 2.13}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 45.63, 'lon': 85.18},
#  'dt': 1541295204,
#  'id': 1529626,
#  'main': {'grnd_level': 1005.93,
#           'humidity': 82,
#           'pressure': 1005.93,
#           'sea_level': 1052.96,
#           'temp': 271.72,
#           'temp_max': 271.72,
#           'temp_min': 271.72},
#  'name': 'Baijiantan',
#  'sys': {'country': 'CN',
#          'message': 0.0076,
#          'sunrise': 1541293362,
#          'sunset': 1541329338},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 16.5012, 'speed': 1.91}}
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': -31.47, 'lon': 19.78},
#  'dt': 1541295204,
#  'id': 3369174,
#  'main': {'grnd_level': 910.44,
#           'humidity': 59,
#           'pressure': 910.44,
#           'sea_level': 1022.6,
#           'temp': 284.12,
#           'temp_max': 284.12,
#           'temp_min': 284.12},
#  'name': 'Calvinia',
#  'sys': {'country': 'ZA',
#          'message': 0.0032,
#          'sunrise': 1541302895,
#          'sunset': 1541351261},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 255.501, 'speed': 3.58}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 50.68, 'lon': 156.12},
#  'dt': 1541295204,
#  'id': 2121385,
#  'main': {'grnd_level': 1002.77,
#           'humidity': 89,
#           'pressure': 1002.77,
#           'sea_level': 1015.87,
#           'temp': 280.695,
#           'temp_max': 280.695,
#           'temp_min': 280.695},
#  'name': 'Severo-Kurilsk',
#  'sys': {'country': 'RU',
#          'message': 0.0036,
#          'sunrise': 1541277066,
#          'sunset': 1541311578},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 221.001, 'speed': 5.86}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 39.31, 'lon': -74.98},
#  'dt': 1541292960,
#  'id': 4501427,
#  'main': {'humidity': 73,
#           'pressure': 1026,
#           'temp': 283.24,
#           'temp_max': 285.35,
#           'temp_min': 280.95},
#  'name': 'Port Elizabeth',
#  'sys': {'country': 'US',
#          'id': 1971,
#          'message': 0.0045,
#          'sunrise': 1541331071,
#          'sunset': 1541368513,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 260, 'speed': 2.1}}
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': -33.59, 'lon': 26.89},
#  'dt': 1541295205,
#  'id': 964432,
#  'main': {'grnd_level': 1005.77,
#           'humidity': 66,
#           'pressure': 1005.77,
#           'sea_level': 1014.7,
#           'temp': 294.995,
#           'temp_max': 294.995,
#           'temp_min': 294.995},
#  'name': 'Port Alfred',
#  'sys': {'country': 'ZA',
#          'message': 0.0032,
#          'sunrise': 1541300983,
#          'sunset': 1541349762},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 43.5012, 'speed': 6.63}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 38.18, 'lon': -1.13},
#  'dt': 1541293200,
#  'id': 2517679,
#  'main': {'humidity': 81,
#           'pressure': 1017,
#           'temp': 282.65,
#           'temp_max': 283.15,
#           'temp_min': 282.15},
#  'name': 'Fortuna',
#  'sys': {'country': 'ES',
#          'id': 5464,
#          'message': 0.0036,
#          'sunrise': 1541313212,
#          'sunset': 1541350925,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 250, 'speed': 2.6}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 5.28, 'lon': 115.24},
#  'dt': 1541293200,
#  'id': 1733782,
#  'main': {'humidity': 79,
#           'pressure': 1011,
#           'temp': 303.15,
#           'temp_max': 303.15,
#           'temp_min': 303.15},
#  'name': 'Victoria',
#  'sys': {'country': 'BN',
#          'id': 8115,
#          'message': 0.004,
#          'sunrise': 1541282692,
#          'sunset': 1541325611,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'speed': 0.5}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 34.64, 'lon': -120.46},
#  'dt': 1541293080,
#  'id': 5367788,
#  'main': {'humidity': 69,
#           'pressure': 1015,
#           'temp': 293.17,
#           'temp_max': 298.15,
#           'temp_min': 289.65},
#  'name': 'Lompoc',
#  'sys': {'country': 'US',
#          'id': 410,
#          'message': 0.0038,
#          'sunrise': 1541341514,
#          'sunset': 1541379905,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'haze', 'icon': '50n', 'id': 721, 'main': 'Haze'}],
#  'wind': {'deg': 250, 'speed': 4.6}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 32},
#  'cod': 200,
#  'coord': {'lat': 77.48, 'lon': -69.36},
#  'dt': 1541295206,
#  'id': 3831208,
#  'main': {'grnd_level': 1000.58,
#           'humidity': 100,
#           'pressure': 1000.58,
#           'sea_level': 1034.56,
#           'temp': 257.12,
#           'temp_max': 257.12,
#           'temp_min': 257.12},
#  'name': 'Qaanaaq',
#  'sys': {'country': 'GL', 'message': 0.0036, 'sunrise': 0, 'sunset': 0},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 86.5012, 'speed': 3.76}}
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': 20.87, 'lon': -90.4},
#  'dt': 1541295206,
#  'id': 3531368,
#  'main': {'grnd_level': 1028.05,
#           'humidity': 99,
#           'pressure': 1028.05,
#           'sea_level': 1028.15,
#           'temp': 300.045,
#           'temp_max': 300.045,
#           'temp_min': 300.045},
#  'name': 'Celestun',
#  'sys': {'country': 'MX',
#          'message': 0.0032,
#          'sunrise': 1541333137,
#          'sunset': 1541373864},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 84.5012, 'speed': 7.86}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -10.62, 'lon': 150.67},
#  'dt': 1541295207,
#  'id': 2132606,
#  'main': {'grnd_level': 1019.95,
#           'humidity': 100,
#           'pressure': 1019.95,
#           'sea_level': 1022.97,
#           'temp': 298.745,
#           'temp_max': 298.745,
#           'temp_min': 298.745},
#  'name': 'Samarai',
#  'rain': {'3h': 2.1},
#  'sys': {'country': 'PG',
#          'message': 0.0039,
#          'sunrise': 1541273136,
#          'sunset': 1541318172},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 105.001, 'speed': 5.26}}
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': 28.66, 'lon': -17.92},
#  'dt': 1541293200,
#  'id': 2514651,
#  'main': {'humidity': 68,
#           'pressure': 1020,
#           'temp': 294.15,
#           'temp_max': 294.15,
#           'temp_min': 294.15},
#  'name': 'Los Llanos de Aridane',
#  'sys': {'country': 'ES',
#          'id': 5515,
#          'message': 0.0031,
#          'sunrise': 1541316351,
#          'sunset': 1541355853,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 8.7}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 0.53, 'lon': 72.93},
#  'dt': 1541295207,
#  'id': 1337610,
#  'main': {'grnd_level': 1024.49,
#           'humidity': 100,
#           'pressure': 1024.49,
#           'sea_level': 1024.51,
#           'temp': 300.97,
#           'temp_max': 300.97,
#           'temp_min': 300.97},
#  'name': 'Thinadhoo',
#  'rain': {'3h': 0.52},
#  'sys': {'country': 'MV',
#          'message': 0.0031,
#          'sunrise': 1541292535,
#          'sunset': 1541336080},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 47.5012, 'speed': 2.46}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -0.92, 'lon': 100.36},
#  'dt': 1541295207,
#  'id': 1633419,
#  'main': {'grnd_level': 1018.33,
#           'humidity': 100,
#           'pressure': 1018.33,
#           'sea_level': 1023.74,
#           'temp': 300.995,
#           'temp_max': 300.995,
#           'temp_min': 300.995},
#  'name': 'Padang',
#  'sys': {'country': 'ID',
#          'message': 0.0077,
#          'sunrise': 1541285857,
#          'sunset': 1541329593},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 153.001, 'speed': 1.56}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 59.56, 'lon': 150.8},
#  'dt': 1541293200,
#  'id': 2123628,
#  'main': {'humidity': 85,
#           'pressure': 989,
#           'temp': 268.15,
#           'temp_max': 268.15,
#           'temp_min': 268.15},
#  'name': 'Magadan',
#  'sys': {'country': 'RU',
#          'id': 7243,
#          'message': 0.0036,
#          'sunrise': 1541280205,
#          'sunset': 1541310979,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 280, 'speed': 1}}
# {'base': 'stations',
#  'clouds': {'all': 36},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.24},
#  'dt': 1541295208,
#  'id': 3366880,
#  'main': {'grnd_level': 980.15,
#           'humidity': 80,
#           'pressure': 980.15,
#           'sea_level': 1019.77,
#           'temp': 286.945,
#           'temp_max': 286.945,
#           'temp_min': 286.945},
#  'name': 'Hermanus',
#  'sys': {'country': 'ZA',
#          'message': 0.0096,
#          'sunrise': 1541302735,
#          'sunset': 1541351684},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 302.001, 'speed': 2.46}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 40.67, 'lon': 33.6},
#  'dt': 1541295208,
#  'id': 749747,
#  'main': {'grnd_level': 889.36,
#           'humidity': 72,
#           'pressure': 889.36,
#           'sea_level': 1038.9,
#           'temp': 269.72,
#           'temp_max': 269.72,
#           'temp_min': 269.72},
#  'name': 'Ayan',
#  'sys': {'country': 'TR',
#          'message': 0.0027,
#          'sunrise': 1541305143,
#          'sunset': 1541342322},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 44.0012, 'speed': 0.98}}
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 69.7, 'lon': 170.27},
#  'dt': 1541295208,
#  'id': 2122090,
#  'main': {'grnd_level': 1015.17,
#           'humidity': 100,
#           'pressure': 1015.17,
#           'sea_level': 1022.76,
#           'temp': 262.545,
#           'temp_max': 262.545,
#           'temp_min': 262.545},
#  'name': 'Pevek',
#  'sys': {'country': 'RU',
#          'message': 0.003,
#          'sunrise': 1541279904,
#          'sunset': 1541301911},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 112.501, 'speed': 1.01}}
# {'base': 'stations',
#  'clouds': {'all': 68},
#  'cod': 200,
#  'coord': {'lat': 64.42, 'lon': -173.23},
#  'dt': 1541295208,
#  'id': 4031574,
#  'main': {'grnd_level': 1007.55,
#           'humidity': 100,
#           'pressure': 1007.55,
#           'sea_level': 1013.77,
#           'temp': 274.87,
#           'temp_max': 274.87,
#           'temp_min': 274.87},
#  'name': 'Provideniya',
#  'sys': {'country': 'RU',
#          'message': 0.0034,
#          'sunrise': 1541359737,
#          'sunset': 1541386975},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 83.5012, 'speed': 2.16}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': 13.52, 'lon': 35.76},
#  'dt': 1541295209,
#  'id': 376332,
#  'main': {'grnd_level': 957.13,
#           'humidity': 77,
#           'pressure': 957.13,
#           'sea_level': 1022.97,
#           'temp': 294.62,
#           'temp_max': 294.62,
#           'temp_min': 294.62},
#  'name': 'Doka',
#  'sys': {'country': 'SD',
#          'message': 0.0032,
#          'sunrise': 1541302323,
#          'sunset': 1541344125},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 47.0012, 'speed': 1.36}}
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': -16.48, 'lon': -151.75},
#  'dt': 1541295209,
#  'id': 4034551,
#  'main': {'grnd_level': 1023.6,
#           'humidity': 100,
#           'pressure': 1023.6,
#           'sea_level': 1023.78,
#           'temp': 301.295,
#           'temp_max': 301.295,
#           'temp_min': 301.295},
#  'name': 'Faanui',
#  'sys': {'country': 'PF',
#          'message': 0.0039,
#          'sunrise': 1541345284,
#          'sunset': 1541391191},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 340.501, 'speed': 3.18}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 14.29, 'lon': 120.72},
#  'dt': 1541293200,
#  'id': 1682474,
#  'main': {'humidity': 62,
#           'pressure': 1013,
#           'temp': 304.15,
#           'temp_max': 304.15,
#           'temp_min': 304.15},
#  'name': 'Ternate',
#  'sys': {'country': 'PH',
#          'id': 7706,
#          'message': 0.003,
#          'sunrise': 1541281981,
#          'sunset': 1541323685,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'speed': 3.1}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -53.16, 'lon': -70.91},
#  'dt': 1541293200,
#  'id': 3874787,
#  'main': {'humidity': 71,
#           'pressure': 977,
#           'temp': 284.15,
#           'temp_max': 284.15,
#           'temp_min': 284.15},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 4642,
#          'message': 0.0033,
#          'sunrise': 1541321671,
#          'sunset': 1541376061,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 10.3}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 68.22, 'lon': -135.01},
#  'dt': 1541293200,
#  'id': 5882953,
#  'main': {'humidity': 77,
#           'pressure': 1013,
#           'temp': 256.15,
#           'temp_max': 256.15,
#           'temp_min': 256.15},
#  'name': 'Aklavik',
#  'sys': {'country': 'CA',
#          'id': 3535,
#          'message': 0.003,
#          'sunrise': 1541352429,
#          'sunset': 1541375928,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 156.501, 'speed': 1.93}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -20.77, 'lon': 117.15},
#  'dt': 1541295210,
#  'id': 2062276,
#  'main': {'grnd_level': 1009.98,
#           'humidity': 16,
#           'pressure': 1009.98,
#           'sea_level': 1023.05,
#           'temp': 310.92,
#           'temp_max': 310.92,
#           'temp_min': 310.92},
#  'name': 'Roebourne',
#  'sys': {'country': 'AU',
#          'message': 0.0031,
#          'sunrise': 1541280445,
#          'sunset': 1541326961},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 253.001, 'speed': 4.96}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 66, 'lon': 57.56},
#  'dt': 1541295210,
#  'id': 863061,
#  'main': {'grnd_level': 1014.92,
#           'humidity': 93,
#           'pressure': 1014.92,
#           'sea_level': 1024.39,
#           'temp': 270.07,
#           'temp_max': 270.07,
#           'temp_min': 270.07},
#  'name': 'Usinsk',
#  'sys': {'country': 'RU',
#          'message': 0.0039,
#          'sunrise': 1541304902,
#          'sunset': 1541331025},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 77.0012, 'speed': 4.16}}
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 48.68, 'lon': 71.64},
#  'dt': 1541295210,
#  'id': 1526041,
#  'main': {'grnd_level': 987.77,
#           'humidity': 94,
#           'pressure': 987.77,
#           'sea_level': 1051.42,
#           'temp': 270.595,
#           'temp_max': 270.595,
#           'temp_min': 270.595},
#  'name': 'Atasu',
#  'sys': {'country': 'KZ',
#          'message': 0.0032,
#          'sunrise': 1541297049,
#          'sunset': 1541332148},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 214.001, 'speed': 2.51}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': -2.57, 'lon': 150.8},
#  'dt': 1541295211,
#  'id': 2094342,
#  'main': {'grnd_level': 1019.95,
#           'humidity': 100,
#           'pressure': 1019.95,
#           'sea_level': 1021.02,
#           'temp': 301.97,
#           'temp_max': 301.97,
#           'temp_min': 301.97},
#  'name': 'Kavieng',
#  'rain': {'3h': 2.36},
#  'sys': {'country': 'PG',
#          'message': 0.0036,
#          'sunrise': 1541273643,
#          'sunset': 1541317597},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 92.5012, 'speed': 3.73}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 69.44, 'lon': -133.03},
#  'dt': 1541293200,
#  'id': 6170031,
#  'main': {'humidity': 84,
#           'pressure': 1013,
#           'temp': 255.15,
#           'temp_max': 255.15,
#           'temp_min': 255.15},
#  'name': 'Tuktoyaktuk',
#  'sys': {'country': 'CA',
#          'id': 3555,
#          'message': 0.0041,
#          'sunrise': 1541352760,
#          'sunset': 1541374643,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 140, 'speed': 3.1}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -22.35, 'lon': 16.13},
#  'dt': 1541295211,
#  'id': 3353871,
#  'main': {'grnd_level': 890.74,
#           'humidity': 88,
#           'pressure': 890.74,
#           'sea_level': 1026.29,
#           'temp': 286.37,
#           'temp_max': 286.37,
#           'temp_min': 286.37},
#  'name': 'Otjimbingwe',
#  'sys': {'country': 'NA',
#          'message': 0.0037,
#          'sunrise': 1541304558,
#          'sunset': 1541351340},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 127.501, 'speed': 0.88}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 8.96, 'lon': 38.73},
#  'dt': 1541295211,
#  'id': 344979,
#  'main': {'grnd_level': 777.18,
#           'humidity': 82,
#           'pressure': 777.18,
#           'sea_level': 1026.94,
#           'temp': 276.92,
#           'temp_max': 276.92,
#           'temp_min': 276.92},
#  'name': 'Lebu',
#  'sys': {'country': 'ET',
#          'message': 0.0035,
#          'sunrise': 1541301301,
#          'sunset': 1541343725},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 357.501, 'speed': 1.21}}
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': -25.24, 'lon': 130.99},
#  'dt': 1541293200,
#  'id': 6355222,
#  'main': {'humidity': 21,
#           'pressure': 1013,
#           'temp': 306.15,
#           'temp_max': 306.15,
#           'temp_min': 306.15},
#  'name': 'Yulara',
#  'sys': {'country': 'AU',
#          'id': 8160,
#          'message': 0.0032,
#          'sunrise': 1541276769,
#          'sunset': 1541323999,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 3.1}}
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': -34.53, 'lon': 20.04},
#  'dt': 1541293200,
#  'id': 1015776,
#  'main': {'humidity': 68,
#           'pressure': 1004,
#           'temp': 292.15,
#           'temp_max': 292.15,
#           'temp_min': 292.15},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA',
#          'id': 6591,
#          'message': 0.0046,
#          'sunrise': 1541302532,
#          'sunset': 1541351503,
#          'type': 1},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 6.7}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 18.74, 'lon': 7.39},
#  'dt': 1541295212,
#  'id': 2447513,
#  'main': {'grnd_level': 971.8,
#           'humidity': 30,
#           'pressure': 971.8,
#           'sea_level': 1024.63,
#           'temp': 290.72,
#           'temp_max': 290.72,
#           'temp_min': 290.72},
#  'name': 'Arlit',
#  'sys': {'country': 'NE',
#          'message': 0.0074,
#          'sunrise': 1541309502,
#          'sunset': 1541350560},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 102.501, 'speed': 2.26}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 65.61, 'lon': -37.64},
#  'dt': 1541292600,
#  'id': 3424607,
#  'main': {'humidity': 53,
#           'pressure': 995,
#           'temp': 267.15,
#           'temp_max': 267.15,
#           'temp_min': 267.15},
#  'name': 'Tasiilaq',
#  'sys': {'country': 'GL',
#          'id': 4806,
#          'message': 0.0035,
#          'sunrise': 1541327629,
#          'sunset': 1541353996,
#          'type': 1},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 240, 'speed': 2.1}}
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 71.64, 'lon': 128.87},
#  'dt': 1541295213,
#  'id': 2015306,
#  'main': {'grnd_level': 1006.01,
#           'humidity': 75,
#           'pressure': 1006.01,
#           'sea_level': 1024.67,
#           'temp': 255.27,
#           'temp_max': 255.27,
#           'temp_min': 255.27},
#  'name': 'Tiksi',
#  'sys': {'country': 'RU',
#          'message': 0.0039,
#          'sunrise': 1541291520,
#          'sunset': 1541310161},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 219.001, 'speed': 4.41}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -10.16, 'lon': 123.6},
#  'dt': 1541295213,
#  'id': 2057087,
#  'main': {'grnd_level': 1012.33,
#           'humidity': 72,
#           'pressure': 1012.33,
#           'sea_level': 1022.89,
#           'temp': 305.12,
#           'temp_max': 305.12,
#           'temp_min': 305.12},
#  'name': 'Kupang',
#  'sys': {'country': 'ID',
#          'message': 0.003,
#          'sunrise': 1541279663,
#          'sunset': 1541324638},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 110.501, 'speed': 3.41}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -42.78, 'lon': 147.06},
#  'dt': 1541293200,
#  'id': 2155415,
#  'main': {'humidity': 48,
#           'pressure': 1005,
#           'temp': 289.15,
#           'temp_max': 289.15,
#           'temp_min': 289.15},
#  'name': 'New Norfolk',
#  'sys': {'country': 'AU',
#          'id': 8195,
#          'message': 0.0037,
#          'sunrise': 1541271120,
#          'sunset': 1541321959,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'speed': 3.6}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 21.35, 'lon': -158.09},
#  'dt': 1541293020,
#  'id': 5850554,
#  'main': {'humidity': 54,
#           'pressure': 1014,
#           'temp': 300.62,
#           'temp_max': 302.05,
#           'temp_min': 299.15},
#  'name': 'Makakilo City',
#  'sys': {'country': 'US',
#          'id': 830,
#          'message': 0.0039,
#          'sunrise': 1541349424,
#          'sunset': 1541390068,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'shower rain',
#               'icon': '09n',
#               'id': 521,
#               'main': 'Rain'}],
#  'wind': {'deg': 70, 'gust': 9.8, 'speed': 4.6}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -32.72, 'lon': 152.14},
#  'dt': 1541293200,
#  'id': 2155562,
#  'main': {'humidity': 73,
#           'pressure': 1014,
#           'temp': 295.15,
#           'temp_max': 295.15,
#           'temp_min': 295.15},
#  'name': 'Nelson Bay',
#  'sys': {'country': 'AU',
#          'id': 8242,
#          'message': 0.0039,
#          'sunrise': 1541271027,
#          'sunset': 1541319596,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 100, 'speed': 4.1}}
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 15.34, 'lon': 74.49},
#  'dt': 1541295214,
#  'id': 1273574,
#  'main': {'grnd_level': 961.67,
#           'humidity': 93,
#           'pressure': 961.67,
#           'sea_level': 1026.66,
#           'temp': 296.845,
#           'temp_max': 296.845,
#           'temp_min': 296.845},
#  'name': 'Vaini',
#  'sys': {'country': 'IN',
#          'message': 0.0037,
#          'sunrise': 1541293152,
#          'sunset': 1541334704},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 89.0012, 'speed': 2.63}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 30.37, 'lon': -88.56},
#  'dt': 1541292960,
#  'id': 4440397,
#  'main': {'humidity': 86,
#           'pressure': 1021,
#           'temp': 288.72,
#           'temp_max': 292.05,
#           'temp_min': 285.15},
#  'name': 'Pascagoula',
#  'sys': {'country': 'US',
#          'id': 1699,
#          'message': 0.0037,
#          'sunrise': 1541333461,
#          'sunset': 1541372650,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 70, 'speed': 1.5}}
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': 30.78, 'lon': 78.62},
#  'dt': 1541295214,
#  'id': 1253628,
#  'main': {'grnd_level': 787.79,
#           'humidity': 99,
#           'pressure': 787.79,
#           'sea_level': 1032.69,
#           'temp': 278.92,
#           'temp_max': 278.92,
#           'temp_min': 278.92},
#  'name': 'Lata',
#  'sys': {'country': 'IN',
#          'message': 0.0038,
#          'sunrise': 1541293351,
#          'sunset': 1541332511},
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 55.5012, 'speed': 0.83}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 32.63, 'lon': -16.97},
#  'dt': 1541293200,
#  'id': 2270380,
#  'main': {'humidity': 82,
#           'pressure': 1023,
#           'temp': 291.15,
#           'temp_max': 291.15,
#           'temp_min': 291.15},
#  'name': 'Camara de Lobos',
#  'sys': {'country': 'PT',
#          'id': 5952,
#          'message': 0.0033,
#          'sunrise': 1541316472,
#          'sunset': 1541355273,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09n',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 20, 'speed': 5.7}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -17.47, 'lon': -70.03},
#  'dt': 1541295215,
#  'id': 3927774,
#  'main': {'grnd_level': 698.22,
#           'humidity': 89,
#           'pressure': 698.22,
#           'sea_level': 1028.4,
#           'temp': 274.295,
#           'temp_max': 274.295,
#           'temp_min': 274.295},
#  'name': 'Tarata',
#  'sys': {'country': 'PE',
#          'message': 0.0031,
#          'sunrise': 1541325604,
#          'sunset': 1541371647},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 327.501, 'speed': 0.21}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -2.39, 'lon': 40.44},
#  'dt': 1541295215,
#  'id': 178093,
#  'main': {'grnd_level': 1021.24,
#           'humidity': 89,
#           'pressure': 1021.24,
#           'sea_level': 1025.93,
#           'temp': 298.07,
#           'temp_max': 298.07,
#           'temp_min': 298.07},
#  'name': 'Witu',
#  'rain': {'3h': 0.115},
#  'sys': {'country': 'KE',
#          'message': 0.0107,
#          'sunrise': 1541300140,
#          'sunset': 1541344072},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 178.001, 'speed': 2.73}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 17.54, 'lon': 44.22},
#  'dt': 1541293200,
#  'id': 103630,
#  'main': {'humidity': 55,
#           'pressure': 1019,
#           'temp': 290.15,
#           'temp_max': 290.15,
#           'temp_min': 290.15},
#  'name': 'Najran',
#  'sys': {'country': 'SA',
#          'id': 6998,
#          'message': 0.0084,
#          'sunrise': 1541300574,
#          'sunset': 1541341811,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 284.501, 'speed': 1.16}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -54.81, 'lon': -68.31},
#  'dt': 1541293200,
#  'id': 3833367,
#  'main': {'humidity': 54,
#           'pressure': 979,
#           'temp': 285.15,
#           'temp_max': 285.15,
#           'temp_min': 285.15},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 4754,
#          'message': 0.004,
#          'sunrise': 1541320688,
#          'sunset': 1541375803,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 360, 'speed': 4.6}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 42.65, 'lon': -73.75},
#  'dt': 1541292840,
#  'id': 5106834,
#  'main': {'humidity': 62,
#           'pressure': 1021,
#           'temp': 279.39,
#           'temp_max': 280.35,
#           'temp_min': 278.75},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 2088,
#          'message': 0.0037,
#          'sunrise': 1541331161,
#          'sunset': 1541367830,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 290, 'gust': 9.8, 'speed': 5.7}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 62.45, 'lon': -114.38},
#  'dt': 1541293200,
#  'id': 6185377,
#  'main': {'humidity': 92,
#           'pressure': 1012,
#           'temp': 262.15,
#           'temp_max': 262.15,
#           'temp_min': 262.15},
#  'name': 'Yellowknife',
#  'sys': {'country': 'CA',
#          'id': 3558,
#          'message': 0.0035,
#          'sunrise': 1541344847,
#          'sunset': 1541373620,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 290, 'speed': 2.6}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -46.19, 'lon': 168.86},
#  'dt': 1541295216,
#  'id': 6201424,
#  'main': {'grnd_level': 993.61,
#           'humidity': 73,
#           'pressure': 993.61,
#           'sea_level': 1008.42,
#           'temp': 283.695,
#           'temp_max': 283.695,
#           'temp_min': 283.695},
#  'name': 'Mataura',
#  'rain': {'3h': 0.135},
#  'sys': {'country': 'NZ',
#          'message': 0.0035,
#          'sunrise': 1541265418,
#          'sunset': 1541317204},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 266.001, 'speed': 11.16}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.64, 'lon': 115.35},
#  'dt': 1541295216,
#  'id': 2075265,
#  'main': {'grnd_level': 1026.68,
#           'humidity': 94,
#           'pressure': 1026.68,
#           'sea_level': 1027.71,
#           'temp': 291.57,
#           'temp_max': 291.57,
#           'temp_min': 291.57},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'message': 0.0031,
#          'sunrise': 1541279761,
#          'sunset': 1541328523},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 268.001, 'speed': 6.73}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 60.91, 'lon': -46.05},
#  'dt': 1541292600,
#  'id': 3421719,
#  'main': {'humidity': 48,
#           'pressure': 1012,
#           'temp': 266.15,
#           'temp_max': 266.15,
#           'temp_min': 266.15},
#  'name': 'Narsaq',
#  'sys': {'country': 'GL',
#          'id': 4791,
#          'message': 0.0044,
#          'sunrise': 1541327920,
#          'sunset': 1541357751,
#          'type': 1},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 90, 'speed': 2.6}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 7.04, 'lon': 134.26},
#  'dt': 1541292600,
#  'id': 7671223,
#  'main': {'humidity': 74,
#           'pressure': 1011,
#           'temp': 303.15,
#           'temp_max': 303.15,
#           'temp_min': 303.15},
#  'name': 'Kloulklubed',
#  'sys': {'country': 'PW',
#          'id': 4054,
#          'message': 0.0034,
#          'sunrise': 1541278243,
#          'sunset': 1541320929,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 90, 'speed': 3.1}}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -17.53, 'lon': -149.33},
#  'dt': 1541293200,
#  'id': 4033356,
#  'main': {'humidity': 74,
#           'pressure': 1010,
#           'temp': 302.15,
#           'temp_max': 302.15,
#           'temp_min': 302.15},
#  'name': 'Tiarei',
#  'sys': {'country': 'PF',
#          'id': 8343,
#          'message': 0.0036,
#          'sunrise': 1541344626,
#          'sunset': 1541390689,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 7.2}}
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 48.65, 'lon': -53.11},
#  'dt': 1541295217,
#  'id': 5905393,
#  'main': {'grnd_level': 1021.33,
#           'humidity': 79,
#           'pressure': 1021.33,
#           'sea_level': 1023.49,
#           'temp': 286.095,
#           'temp_max': 286.095,
#           'temp_min': 286.095},
#  'name': 'Bonavista',
#  'rain': {'3h': 0.59},
#  'sys': {'country': 'CA',
#          'message': 0.0031,
#          'sunrise': 1541327017,
#          'sunset': 1541362060},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 199.001, 'speed': 10.78}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -46.57, 'lon': -67.67},
#  'dt': 1541295217,
#  'id': 3863379,
#  'main': {'grnd_level': 977.23,
#           'humidity': 39,
#           'pressure': 977.23,
#           'sea_level': 1006.03,
#           'temp': 288.92,
#           'temp_max': 288.92,
#           'temp_min': 288.92},
#  'name': 'Lujan',
#  'sys': {'country': 'AR',
#          'message': 0.0031,
#          'sunrise': 1541322070,
#          'sunset': 1541374088},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 335.501, 'speed': 8.36}}
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 65.28, 'lon': -126.83},
#  'dt': 1541293680,
#  'id': 6089245,
#  'main': {'humidity': 84,
#           'pressure': 1014,
#           'temp': 258.15,
#           'temp_max': 258.15,
#           'temp_min': 258.15},
#  'name': 'Norman Wells',
#  'sys': {'country': 'CA',
#          'id': 3547,
#          'message': 0.0103,
#          'sunrise': 1541348940,
#          'sunset': 1541375498,
#          'type': 1},
#  'visibility': 48279,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 100, 'speed': 3.6}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 15.09, 'lon': -87.97},
#  'dt': 1541293200,
#  'id': 3603330,
#  'main': {'humidity': 83,
#           'pressure': 1011,
#           'temp': 300.15,
#           'temp_max': 300.15,
#           'temp_min': 300.15},
#  'name': 'Amapa',
#  'sys': {'country': 'HN',
#          'id': 4191,
#          'message': 0.011,
#          'sunrise': 1541332135,
#          'sunset': 1541373704,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 360, 'speed': 3.1}}
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 11.28, 'lon': 49.18},
#  'dt': 1541295218,
#  'id': 64013,
#  'main': {'grnd_level': 1018.33,
#           'humidity': 100,
#           'pressure': 1018.33,
#           'sea_level': 1026.45,
#           'temp': 298.095,
#           'temp_max': 298.095,
#           'temp_min': 298.095},
#  'name': 'Bosaso',
#  'sys': {'country': 'SO',
#          'message': 0.0036,
#          'sunrise': 1541298949,
#          'sunset': 1541341059},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 77.0012, 'speed': 3.41}}
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': -5.67, 'lon': 132.75},
#  'dt': 1541295218,
#  'id': 1623197,
#  'main': {'grnd_level': 1022.22,
#           'humidity': 100,
#           'pressure': 1022.22,
#           'sea_level': 1022.8,
#           'temp': 299.82,
#           'temp_max': 299.82,
#           'temp_min': 299.82},
#  'name': 'Tual',
#  'rain': {'3h': 0.89},
#  'sys': {'country': 'ID',
#          'message': 0.0032,
#          'sunrise': 1541277770,
#          'sunset': 1541322136},
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 320.001, 'speed': 0.91}}
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': -2.72, 'lon': 17.69},
#  'dt': 1541295218,
#  'id': 2311968,
#  'main': {'grnd_level': 986.39,
#           'humidity': 98,
#           'pressure': 986.39,
#           'sea_level': 1022.8,
#           'temp': 296.045,
#           'temp_max': 296.045,
#           'temp_min': 296.045},
#  'name': 'Nioki',
#  'sys': {'country': 'CD',
#          'message': 0.0035,
#          'sunrise': 1541305578,
#          'sunset': 1541349555},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 67.0012, 'speed': 0.81}}
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': -34.58, 'lon': 150.85},
#  'dt': 1541293200,
#  'id': 6255012,
#  'main': {'humidity': 41,
#           'pressure': 1012,
#           'temp': 299.15,
#           'temp_max': 299.15,
#           'temp_min': 299.15},
#  'name': 'Flinders',
#  'sys': {'country': 'AU',
#          'id': 8231,
#          'message': 0.0036,
#          'sunrise': 1541271152,
#          'sunset': 1541320093,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
# ...
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 120.501, 'speed': 3.58}}
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': -7.19, 'lon': -48.21},
#  'dt': 1541295327,
#  'id': 3407357,
#  'main': {'grnd_level': 996.52,
#           'humidity': 88,
#           'pressure': 996.52,
#           'sea_level': 1022.16,
#           'temp': 297.295,
#           'temp_max': 297.295,
#           'temp_min': 297.295},
#  'name': 'Araguaina',
#  'sys': {'country': 'BR',
#          'message': 0.0038,
#          'sunrise': 1541321094,
#          'sunset': 1541365675},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 273.001, 'speed': 1.11}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 44.08, 'lon': -80.2},
#  'dt': 1541293200,
#  'id': 6145890,
#  'main': {'humidity': 69,
#           'pressure': 1023,
#           'temp': 276.49,
#           'temp_max': 277.15,
#           'temp_min': 276.15},
#  'name': 'Shelburne',
#  'sys': {'country': 'CA',
#          'id': 3632,
#          'message': 0.0051,
#          'sunrise': 1541332888,
#          'sunset': 1541369197,
#          'type': 1},
#  'visibility': 14484,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'speed': 4.1}}
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': 41.26, 'lon': 125.37},
#  'dt': 1541295328,
#  'id': 2036713,
#  'main': {'grnd_level': 978.77,
#           'humidity': 81,
#           'pressure': 978.77,
#           'sea_level': 1038,
#           'temp': 282.495,
#           'temp_max': 282.495,
#           'temp_min': 282.495},
#  'name': 'Huanren',
#  'sys': {'country': 'CN',
#          'message': 0.0089,
#          'sunrise': 1541283167,
#          'sunset': 1541320246},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 183.001, 'speed': 1.36}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -1.76, 'lon': -48.8},
#  'dt': 1541293200,
#  'id': 3408424,
#  'main': {'humidity': 83,
#           'pressure': 1090,
#           'temp': 299.15,
#           'temp_max': 299.15,
#           'temp_min': 299.15},
#  'name': 'Ipixuna',
#  'sys': {'country': 'BR',
#          'id': 4457,
#          'message': 0.0038,
#          'sunrise': 1541321599,
#          'sunset': 1541365449,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 60, 'speed': 4.1}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 60.06, 'lon': 69.92},
#  'dt': 1541295328,
#  'id': 1506268,
#  'main': {'grnd_level': 1023.35,
#           'humidity': 94,
#           'pressure': 1023.35,
#           'sea_level': 1032.73,
#           'temp': 268.095,
#           'temp_max': 268.095,
#           'temp_min': 268.095},
#  'name': 'Gornopravdinsk',
#  'sys': {'country': 'RU',
#          'message': 0.003,
#          'sunrise': 1541299789,
#          'sunset': 1541330217},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 173.501, 'speed': 2.73}}
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': -16.78, 'lon': -151.5},
#  'dt': 1541295328,
#  'id': 4033375,
#  'main': {'grnd_level': 1022.7,
#           'humidity': 100,
#           'pressure': 1022.7,
#           'sea_level': 1023.98,
#           'temp': 300.07,
#           'temp_max': 300.07,
#           'temp_min': 300.07},
#  'name': 'Tevaitoa',
#  'sys': {'country': 'PF',
#          'message': 0.0037,
#          'sunrise': 1541345202,
#          'sunset': 1541391154},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 306.501, 'speed': 2.16}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 24.82, 'lon': 79.14},
#  'dt': 1541295329,
#  'id': 1266931,
#  'main': {'grnd_level': 985.66,
#           'humidity': 41,
#           'pressure': 985.66,
#           'sea_level': 1026.41,
#           'temp': 302.07,
#           'temp_max': 302.07,
#           'temp_min': 302.07},
#  'name': 'Khargapur',
#  'sys': {'country': 'IN',
#          'message': 0.0125,
#          'sunrise': 1541292734,
#          'sunset': 1541332884},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 274.001, 'speed': 2.16}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 50.7, 'lon': -127.42},
#  'dt': 1541293200,
#  'id': 6111862,
#  'main': {'humidity': 100,
#           'pressure': 1003,
#           'temp': 283.15,
#           'temp_max': 283.15,
#           'temp_min': 283.15},
#  'name': 'Port Hardy',
#  'sys': {'country': 'CA',
#          'id': 3322,
#          'message': 0.0057,
#          'sunrise': 1541345200,
#          'sunset': 1541379545,
#          'type': 1},
#  'visibility': 3219,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'},
#              {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 140, 'speed': 5.1}}
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 44.43, 'lon': 125.17},
#  'dt': 1541293200,
#  'id': 2035565,
#  'main': {'humidity': 64,
#           'pressure': 1028,
#           'temp': 275.15,
#           'temp_max': 275.15,
#           'temp_min': 275.15},
#  'name': 'Nongan',
#  'sys': {'country': 'CN',
#          'id': 7467,
#          'message': 0.0041,
#          'sunrise': 1541283599,
#          'sunset': 1541319908,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 20, 'speed': 4}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 61.12, 'lon': 27.27},
#  'dt': 1541294400,
#  'id': 637314,
#  'main': {'humidity': 100,
#           'pressure': 1023,
#           'temp': 274.48,
#           'temp_max': 275.15,
#           'temp_min': 274.15},
#  'name': 'Tornio',
#  'sys': {'country': 'FI',
#          'id': 5047,
#          'message': 0.0046,
#          'sunrise': 1541310354,
#          'sunset': 1541340122,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 260, 'speed': 3.1}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.38, 'lon': 33.78},
#  'dt': 1541295330,
#  'id': 743882,
#  'main': {'grnd_level': 908.98,
#           'humidity': 79,
#           'pressure': 908.98,
#           'sea_level': 1038.94,
#           'temp': 270.37,
#           'temp_max': 270.37,
#           'temp_min': 270.37},
#  'name': 'Kastamonu',
#  'sys': {'country': 'TR',
#          'message': 0.0069,
#          'sunrise': 1541305181,
#          'sunset': 1541342196},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 98.0012, 'speed': 1.01}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 30.28, 'lon': -98.87},
#  'dt': 1541292900,
#  'id': 4692279,
#  'main': {'humidity': 70,
#           'pressure': 1013,
#           'temp': 291.87,
#           'temp_max': 293.75,
#           'temp_min': 290.15},
#  'name': 'Fredericksburg',
#  'sys': {'country': 'US',
#          'id': 2613,
#          'message': 0.0042,
#          'sunrise': 1541335929,
#          'sunset': 1541375131,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 170, 'speed': 1.5}}
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'cod': '404', 'message': 'city not found'}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 23.86, 'lon': 116.89},
#  'dt': 1541293200,
#  'id': 1810927,
#  'main': {'humidity': 88,
#           'pressure': 1019,
#           'temp': 296.15,
#           'temp_max': 296.15,
#           'temp_min': 296.15},
#  'name': 'Fushan',
#  'sys': {'country': 'CN',
#          'id': 7418,
#          'message': 0.0037,
#          'sunrise': 1541283595,
#          'sunset': 1541323903,
#          'type': 1},
#  'visibility': 6000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'speed': 1}}
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': 24.08, 'lon': 89.61},
#  'dt': 1541295331,
#  'id': 1209562,
#  'main': {'grnd_level': 1026.76,
#           'humidity': 80,
#           'pressure': 1026.76,
#           'sea_level': 1028.56,
#           'temp': 299.195,
#           'temp_max': 299.195,
#           'temp_min': 299.195},
#  'name': 'Bera',
#  'sys': {'country': 'BD',
#          'message': 0.0034,
#          'sunrise': 1541290162,
#          'sunset': 1541330431},
#  'weather': [{'description': 'clear sky',
#               'icon': '02d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 153.501, 'speed': 2.13}}
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 57.69, 'lon': 71.17},
#  'dt': 1541295331,
#  'id': 1488206,
#  'main': {'grnd_level': 1028.22,
#           'humidity': 91,
#           'pressure': 1028.22,
#           'sea_level': 1037.76,
#           'temp': 266.82,
#           'temp_max': 266.82,
#           'temp_min': 266.82},
#  'name': 'Ust-Ishim',
#  'sys': {'country': 'RU',
#          'message': 0.0088,
#          'sunrise': 1541298871,
#          'sunset': 1541330539},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 194.001, 'speed': 3.93}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 39.75, 'lon': -75.55},
#  'dt': 1541292900,
#  'id': 4145381,
#  'main': {'humidity': 58,
#           'pressure': 1026,
#           'temp': 282.11,
#           'temp_max': 283.75,
#           'temp_min': 280.15},
#  'name': 'Wilmington',
#  'sys': {'country': 'US',
#          'id': 636,
#          'message': 0.0039,
#          'sunrise': 1541331257,
#          'sunset': 1541368601,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 270, 'speed': 3.6}}
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 51.04, 'lon': -4.21},
#  'dt': 1541292600,
#  'id': 2641434,
#  'main': {'humidity': 93,
#           'pressure': 1009,
#           'temp': 285.15,
#           'temp_max': 285.15,
#           'temp_min': 285.15},
#  'name': 'Northam',
#  'rain': {'3h': 0.4},
#  'sys': {'country': 'GB',
#          'id': 5071,
#          'message': 0.008,
#          'sunrise': 1541315651,
#          'sunset': 1541349951,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 190, 'speed': 5.7}}
# {'base': 'stations',
#  'clouds': {'all': 12},
#  'cod': 200,
#  'coord': {'lat': 49.36, 'lon': 25.65},
#  'dt': 1541295332,
#  'id': 691693,
#  'main': {'grnd_level': 999.93,
#           'humidity': 91,
#           'pressure': 999.93,
#           'sea_level': 1039.38,
#           'temp': 281.595,
#           'temp_max': 281.595,
#           'temp_min': 281.595},
#  'name': 'Druzhba',
#  'sys': {'country': 'UA',
#          'message': 0.0034,
#          'sunrise': 1541308203,
#          'sunset': 1541343068},
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 92.5012, 'speed': 1.96}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 26.46, 'lon': 111.6},
#  'dt': 1541295332,
#  'id': 1804162,
#  'main': {'grnd_level': 1006.01,
#           'humidity': 69,
#           'pressure': 1006.01,
#           'sea_level': 1031.76,
#           'temp': 294.845,
#           'temp_max': 294.845,
#           'temp_min': 294.845},
#  'name': 'Yongzhou',
#  'sys': {'country': 'CN',
#          'message': 0.0044,
#          'sunrise': 1541285070,
#          'sunset': 1541324966},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 41.5012, 'speed': 1.71}}
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 56.73, 'lon': 85.44},
#  'dt': 1541295332,
#  'id': 1511846,
#  'main': {'grnd_level': 1023.03,
#           'humidity': 73,
#           'pressure': 1023.03,
#           'sea_level': 1041.61,
#           'temp': 263.42,
#           'temp_max': 263.42,
#           'temp_min': 263.42},
#  'name': 'Oktyabrskoye',
#  'sys': {'country': 'RU',
#          'message': 0.0115,
#          'sunrise': 1541295217,
#          'sunset': 1541327345},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260.501, 'speed': 3.03}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 29.16, 'lon': 16.14},
#  'dt': 1541295332,
#  'id': 2209055,
#  'main': {'grnd_level': 979.58,
#           'humidity': 66,
#           'pressure': 979.58,
#           'sea_level': 1026.98,
#           'temp': 285.92,
#           'temp_max': 285.92,
#           'temp_min': 285.92},
#  'name': 'Waddan',
#  'sys': {'country': 'LY',
#          'message': 0.0034,
#          'sunrise': 1541308215,
#          'sunset': 1541347640},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 129.501, 'speed': 2.11}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -30.67, 'lon': -51.4},
#  'dt': 1541295195,
#  'id': 3446880,
#  'main': {'grnd_level': 1012.98,
#           'humidity': 97,
#           'pressure': 1012.98,
#           'sea_level': 1027.26,
#           'temp': 289.22,
#           'temp_max': 289.22,
#           'temp_min': 289.22},
#  'name': 'Tapes',
#  'sys': {'country': 'BR',
#          'message': 0.0034,
#          'sunrise': 1541320044,
#          'sunset': 1541368278},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 135.001, 'speed': 2.83}}
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 1.61, 'lon': 16.05},
#  'dt': 1541295333,
#  'id': 2255564,
#  'main': {'grnd_level': 982.34,
#           'humidity': 97,
#           'pressure': 982.34,
#           'sea_level': 1023.05,
#           'temp': 295.87,
#           'temp_max': 295.87,
#           'temp_min': 295.87},
#  'name': 'Ouesso',
#  'sys': {'country': 'CG',
#          'message': 0.0493,
#          'sunrise': 1541306258,
#          'sunset': 1541349660},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 122.001, 'speed': 1.01}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -9.67, 'lon': -35.74},
#  'dt': 1541293200,
#  'id': 3395981,
#  'main': {'humidity': 83,
#           'pressure': 1013,
#           'temp': 297.15,
#           'temp_max': 297.15,
#           'temp_min': 297.15},
#  'name': 'Maceio',
#  'sys': {'country': 'BR',
#          'id': 4538,
#          'message': 0.0051,
#          'sunrise': 1541317932,
#          'sunset': 1541362853,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 3.1}}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#I can't figure it out
#Spent over 4 hours on trying to export to a csv/just make a data frame and I can't do it.

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
